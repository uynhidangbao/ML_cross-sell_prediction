# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV,RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
from sklearn.metrics import (
    accuracy_score, recall_score, precision_score, f1_score,
    classification_report, confusion_matrix, roc_auc_score, roc_curve
)

# %%
#Dataset
df = pd.read_csv("Pre-processingDataset (1).csv", encoding="latin1")

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   76                1            3                   0
# 1   2    Male   21                1           11                   1
# 2   3  Female   29                1           41                   1
# 3   4  Female   24                1           33                   0
# 4   5    Male   23                1           11                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year             No           33536                    26      183
# 1    < 1 Year             No           28619                   152      203
# 2    < 1 Year             No           27496                   152       39
# 3    < 1 Year            Yes            2630                   160      176
# 4    < 1 Year            Yes           23367                   152      249
#
#    Response  Year                                            Product  \
# 0         0  2019                          Critical Illness Coverage
# 1         0  2019                           Vision Exams and Eyewear
# 2         0  2019  Prescription Drugs Coverage, Hospitalization C...
# 3         0  2019  Surgery Coverage, Emergency Room Visits, Mater...
# 4         0  2019      Pediatric Services, Physical Therapy Coverage
#
#       Premium_Bin Age_Generation
# 0  Extremely High         Silent
# 1  Extremely High          Gen Z
# 2  Extremely High    Millennials
# 3        Very Low          Gen Z
# 4       Very High          Gen Z

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  int64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  int64
#  9   Policy_Sales_Channel  381109 non-null  int64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
#  12  Year                  381109 non-null  int64
#  13  Product               381109 non-null  object
#  14  Premium_Bin           381109 non-null  object
#  15  Age_Generation        381109 non-null  object
# dtypes: int64(10), object(6)
# memory usage: 46.5+ MB

# %%
df.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# 25%              0.000000    24405.000000             29.000000
# 50%              0.000000    31669.000000            133.000000
# 75%              1.000000    39400.000000            152.000000
# max              1.000000   540165.000000            163.000000
#
#              Vintage       Response           Year
# count  381109.000000  381109.000000  381109.000000
# mean      154.347397       0.122563    2020.982278
# std        83.671304       0.327936       1.411540
# min        10.000000       0.000000    2019.000000
# 25%        82.000000       0.000000    2020.000000
# 50%       154.000000       0.000000    2021.000000
# 75%       227.000000       0.000000    2022.000000
# max       299.000000       1.000000    2023.000000

# %%
df.describe(include = 'O')
# Out:
#         Gender Vehicle_Age Vehicle_Damage  \
# count   381109      381109         381109
# unique       2           3              2
# top       Male    1-2 Year            Yes
# freq    206089      200316         192413
#
#                                               Product     Premium_Bin  \
# count                                          381109          381109
# unique                                            229               6
# top     Pediatric Services, Physical Therapy Coverage  Extremely High
# freq                                            24103          280146
#
#        Age_Generation
# count          381109
# unique              5
# top       Millennials
# freq           115587

# %%
df_unique = df.drop(columns = 'id')

for column in df_unique.columns:
    print(f"{column}: ")
    print("")
    print(df_unique[column].unique())
    print("")
# Out:
# Gender:
#
# ['Male' 'Female']
#
# Age:
#
# [76 21 29 24 23 32 41 71 25 42 65 49 44 34 26 79 48 45 72 30 54 27 38 56
#  51 22 78 20 39 62 58 59 60 63 50 67 77 28 69 52 31 33 37 36 47 53 70 55
#  40 75 64 57 35 43 46 66 68 73 84 61 83 81 74 80 82 85]
#
# Driving_License:
#
# [1 0]
#
# Region_Code:
#
# [ 3 11 41 33  6 50 15 28 45 35  8 36 30 26 16 47 48 19 39 23 37  5 17  2
#   7 29 46 27 25 13 20 49 22  0  9 31 12 34 21 10 14 18 24 40 43 38 32 44
#   4 51 42  1 52]
#
# Previously_Insured:
#
# [0 1]
#
# Vehicle_Age:
#
# ['1-2 Year' '< 1 Year' '> 2 Years']
#
# Vehicle_Damage:
#
# ['No' 'Yes']
#
# Annual_Premium:
#
# [33536 28619 27496 ... 52918 67320 69184]
#
# Policy_Sales_Channel:
#
# [ 26 152 160  14  13  30 124 163 122  19  22  15 156 154  16  52 155  11
#  151 125  25  61   1  86 157 150  23  60  21   3 139  12  29  55   7  47
#  127 153  78  89  32   8  10 120  65   4  42  83 136  18  56  48  93 116
#   91  45   9 158 145 147  24  44 109  37 140 128 114 118 159 119 105  31
#  107 135  62 138 131 129  88 111 113  73  36  28  35  59  53 148 133 108
#  121  64  39  94 132  46  81  54 103  90  51  27 146 106  63  96  40  66
#  100  92  95  98  75 130 134  49  38  17 110  80  71 117  58  20  76 104
#   84 137  69 126  97  68  67 101 115  57  82  79 112  87  99  70   2  34
#   33  74 102 149   6  50 144 143  41 123  43]
#
# Vintage:
#
# [183 203  39 176 249  28  80 289 221  15  58 256 299 158 116 177 232  60
#  180  72  57 223 136 222 149  49 169  88 253 107 264 233  45 184 251 153
#  186  71  34  83  12 246 141 216 130 282  73 171 295 165  30 218  22 147
#   36  79 100  63 242 277  61 111  74 235 131 243 248 114  62 189 139 138
#  209 254 291  68  92  52  78 156 247 275  77 181 166  16  23  31 293 219
#   50  66 260 258 117 193 204 212 144 206 228 125  29  18  84 230  54 123
#  101  86  13 237  85  98  67 229  95  89  99 208 134 135 268 284 119 226
#  142 272  64  40 245 163  24 102 265 202 259  91 106 162  33 194 287 292
#   69 239 132 255 281 167 152 121 150 207 128 143 198 103 127 285 214 151
#  217  56 215 104 238 120  21 270 211 105 200 197  11 213  93 113 178  10
#  290  94 231 296  47 122 271 278 276 190 240 257 224 173 220  32 199 185
#   81  90  51 205  70 137 168 118  19 288  46 126 241  82 227 115 236 155
#  286 108 274 201  59  97  25 174 182 154  48 244  20 283  53  17 261  41
#  266  35 140 269 146 160 234 145  65  27 298 195  55 188 172  75  38  43
#  110  37 129 170 267 279 112  96 280  87  76 191 164 179 175 252  42 124
#  133 187 148 294  44 157 192  26 109 262 159 263 210 250 273 161 297 196
#   14 225]
#
# Response:
#
# [0 1]
#
# Year:
#
# [2019 2020 2021 2022 2023]
#
# Product:
#
# ['Critical Illness Coverage' 'Vision Exams and Eyewear'
#  'Prescription Drugs Coverage, Hospitalization Coverage'
#  'Surgery Coverage, Emergency Room Visits, Maternity and Newborn Care'
#  'Pediatric Services, Physical Therapy Coverage'
#  'Chiropractic Care Coverage, Home Healthcare Services'
#  'Hospice Care Coverage, Medical Equipment and Supplies'
#  'Preventive Services' 'Mental Health Coverage'
#  'Dental Exams and Cleanings, Vision Exams and Eyewear'
#  'Prescription Drugs Coverage' 'Surgery Coverage, Emergency Room Visits'
#  'Maternity and Newborn Care, Pediatric Services'
#  'Physical Therapy Coverage, Occupational Therapy Coverage'
#  'Home Healthcare Services, Hospice Care Coverage'
#  'Medical Equipment and Supplies, Laboratory Services'
#  'Diagnostic Tests Coverage, Preventive Services'
#  'Mental Health Coverage, Dental Exams and Cleanings'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage'
#  'Critical Illness Coverage, Hospitalization Coverage, Surgery Coverage'
#  'Occupational Therapy Coverage, Speech Therapy Coverage'
#  'Laboratory Services, Diagnostic Tests Coverage'
#  'Mental Health Coverage, Vision Exams and Eyewear'
#  'Dental Exams and Cleanings, Prescription Drugs Coverage'
#  'Critical Illness Coverage, Hospitalization Coverage'
#  'Laboratory Services, Diagnostic Tests Coverage, Preventive Services'
#  'Speech Therapy Coverage, Chiropractic Care Coverage'
#  'Emergency Room Visits, Maternity and Newborn Care'
#  'Critical Illness Coverage, Mental Health Coverage, Dental Exams and Cleanings, Vision Exams and Eyewear, Prescription Drugs Coverage, Roadside Assistance'
#  'Hospitalization Coverage, Surgery Coverage, Emergency Room Visits, Maternity and Newborn Care, Pediatric Services, Comprehensive Coverage'
#  'Physical Therapy Coverage, Occupational Therapy Coverage, Speech Therapy Coverage, Chiropractic Care Coverage, Home Healthcare Services, Rental Car Reimbursement'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Laboratory Services, Diagnostic Tests Coverage, Preventive Services, Liability Coverage'
#  'Maternity and Newborn Care, Pediatric Services, Natural Disaster Protection'
#  'Prescription Drugs Coverage, Collision Coverage'
#  'Vision Exams and Eyewear, Personal Accident Insurance, Roadside Assistance'
#  'Preventive Services, Mechanical Breakdown Insurance'
#  'Dental Exams and Cleanings, Comprehensive Coverage, New Car Replacement Coverage'
#  'Emergency Room Visits, Physical Therapy Coverage, Glass Coverage'
#  'Medical Equipment and Supplies, Diagnostic Tests Coverage, Loss of Use Coverage'
#  'Chiropractic Care Coverage, Liability Coverage'
#  'Surgery Coverage, Prescription Drugs Coverage, Roadside Assistance, Gap Insurance'
#  'Home Healthcare Services, Maternity and Newborn Care, Uninsured/Underinsured Motorist Coverage'
#  'Mental Health Coverage, Dental Exams and Cleanings, Collision Coverage'
#  'Pediatric Services, Vision Exams and Eyewear, Personal Accident Insurance, Rental Car Reimbursement'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Natural Disaster Protection'
#  'Hospice Care Coverage, Comprehensive Coverage'
#  'Laboratory Services, Diagnostic Tests Coverage, Preventive Services, Key Replacement Coverage'
#  'Critical Illness Coverage, Medical Equipment and Supplies, Towing and Labor Coverage'
#  'Dental Exams and Cleanings, Prescription Drugs Coverage, Mechanical Breakdown Insurance'
#  'Vision Exams and Eyewear, Surgery Coverage, Roadside Assistance'
#  'Physical Therapy Coverage, Occupational Therapy Coverage, Liability Coverage, Loss of Use Coverage'
#  'Chiropractic Care Coverage, Home Healthcare Services, Rental Car Reimbursement'
#  'Emergency Room Visits, Maternity and Newborn Care, Comprehensive Coverage'
#  'Preventive Services, Medical Equipment and Supplies, Diagnostic Tests Coverage'
#  'Mental Health Coverage, Pediatric Services, Personal Accident Insurance, Glass Coverage'
#  'Dental Exams and Cleanings, Vision Exams and Eyewear, Collision Coverage'
#  'Prescription Drugs Coverage, Roadside Assistance, Gap Insurance'
#  'Surgery Coverage, Emergency Room Visits, Towing and Labor Coverage'
#  'Chiropractic Care Coverage, Home Healthcare Services, Comprehensive Coverage'
#  'Maternity and Newborn Care, Pediatric Services, Natural Disaster Protection, New Car Replacement Coverage'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Liability Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Diagnostic Tests Coverage, Preventive Services'
#  'Critical Illness Coverage, Dental Exams and Cleanings, Personal Accident Insurance'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, Rental Car Reimbursement'
#  'Physical Therapy Coverage, Collision Coverage, Mechanical Breakdown Insurance'
#  'Emergency Room Visits, Maternity and Newborn Care, Roadside Assistance, Loss of Use Coverage'
#  'Preventive Services, Chiropractic Care Coverage, Liability Coverage'
#  'Mental Health Coverage, Home Healthcare Services, Comprehensive Coverage'
#  'Dental Exams and Cleanings, Vision Exams and Eyewear, Prescription Drugs Coverage, Towing and Labor Coverage'
#  'Surgery Coverage, Pediatric Services, Natural Disaster Protection'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Personal Accident Insurance, Diagnostic Tests Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Rental Car Reimbursement, Gap Insurance'
#  'Critical Illness Coverage, Prescription Drugs Coverage, Collision Coverage'
#  'Emergency Room Visits, Maternity and Newborn Care, Home Healthcare Services, Comprehensive Coverage'
#  'Preventive Services, Physical Therapy Coverage, Liability Coverage'
#  'Mental Health Coverage, Dental Exams and Cleanings, Roadside Assistance, New Car Replacement Coverage'
#  'Vision Exams and Eyewear, Surgery Coverage, Personal Accident Insurance, Mechanical Breakdown Insurance'
#  'Chiropractic Care Coverage, Occupational Therapy Coverage, Towing and Labor Coverage'
#  'Pediatric Services, Speech Therapy Coverage, Natural Disaster Protection'
#  'Hospice Care Coverage, Diagnostic Tests Coverage, Preventive Services, Comprehensive Coverage'
#  'Critical Illness Coverage, Dental Exams and Cleanings, Prescription Drugs Coverage, Rental Car Reimbursement'
#  'Emergency Room Visits, Maternity and Newborn Care, Collision Coverage, Loss of Use Coverage'
#  'Mental Health Coverage, Physical Therapy Coverage, Occupational Therapy Coverage, Liability Coverage'
#  'Vision Exams and Eyewear, Surgery Coverage, Home Healthcare Services, Gap Insurance'
#  'Preventive Services, Chiropractic Care Coverage, Medical Equipment and Supplies, Personal Accident Insurance'
#  'Dental Exams and Cleanings, Prescription Drugs Coverage, Roadside Assistance, Mechanical Breakdown Insurance'
#  'Pediatric Services, Emergency Room Visits, Comprehensive Coverage'
#  'Speech Therapy Coverage, Maternity and Newborn Care, Diagnostic Tests Coverage, Natural Disaster Protection'
#  'Critical Illness Coverage, Vision Exams and Eyewear, Hospice Care Coverage'
#  'Dental Exams and Cleanings, Prescription Drugs Coverage, Personal Accident Insurance, Collision Coverage'
#  'Mental Health Coverage, Surgery Coverage, Home Healthcare Services, Loss of Use Coverage'
#  'Emergency Room Visits, Physical Therapy Coverage, Towing and Labor Coverage'
#  'Preventive Services, Occupational Therapy Coverage, Medical Equipment and Supplies, Comprehensive Coverage'
#  'Chiropractic Care Coverage, Pediatric Services, Diagnostic Tests Coverage'
#  'Maternity and Newborn Care, Speech Therapy Coverage, Natural Disaster Protection, Gap Insurance'
#  'Critical Illness Coverage, Dental Exams and Cleanings, Prescription Drugs Coverage, Home Healthcare Services'
#  'Vision Exams and Eyewear, Surgery Coverage, Emergency Room Visits, Rental Car Reimbursement'
#  'Mental Health Coverage, Pediatric Services, Collision Coverage, Comprehensive Coverage'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Medical Equipment and Supplies, Personal Accident Insurance'
#  'Hospice Care Coverage, Preventive Services, Diagnostic Tests Coverage, Natural Disaster Protection'
#  'Critical Illness Coverage, Dental Exams and Cleanings, Prescription Drugs Coverage, Roadside Assistance, Mechanical Breakdown Insurance'
#  'Vision Exams and Eyewear, Emergency Room Visits, Maternity and Newborn Care, Liability Coverage'
#  'Mental Health Coverage, Surgery Coverage, Chiropractic Care Coverage, Home Healthcare Services, Towing and Labor Coverage'
#  'Prescription Drugs Coverage, Pediatric Services, Comprehensive Coverage'
#  'Preventive Services, Physical Therapy Coverage, Diagnostic Tests Coverage, Natural Disaster Protection'
#  'Dental Exams and Cleanings, Collision Coverage, Personal Accident Insurance'
#  'Critical Illness Coverage, Vision Exams and Eyewear, Hospice Care Coverage, Rental Car Reimbursement'
#  'Mental Health Coverage, Emergency Room Visits, Speech Therapy Coverage, Mechanical Breakdown Insurance'
#  'Prescription Drugs Coverage, Maternity and Newborn Care, Home Healthcare Services, Comprehensive Coverage'
#  'Preventive Services, Pediatric Services, Occupational Therapy Coverage, Diagnostic Tests Coverage'
#  'Dental Exams and Cleanings, Prescription Drugs Coverage, Roadside Assistance, Liability Coverage'
#  'Critical Illness Coverage, Vision Exams and Eyewear, Surgery Coverage, Personal Accident Insurance'
#  'Mental Health Coverage, Emergency Room Visits, Chiropractic Care Coverage, Medical Equipment and Supplies'
#  'Prescription Drugs Coverage, Pediatric Services, Home Healthcare Services, Collision Coverage'
#  'Preventive Services, Occupational Therapy Coverage, Diagnostic Tests Coverage, Comprehensive Coverage'
#  'Dental Exams and Cleanings, Maternity and Newborn Care, Natural Disaster Protection, Towing and Labor Coverage'
#  'Critical Illness Coverage, Vision Exams and Eyewear, Prescription Drugs Coverage, Hospice Care Coverage'
#  'Mental Health Coverage, Surgery Coverage, Pediatric Services, Roadside Assistance, Loss of Use Coverage'
#  'Emergency Room Visits, Physical Therapy Coverage, Chiropractic Care Coverage, Comprehensive Coverage'
#  'Prescription Drugs Coverage, Occupational Therapy Coverage, Diagnostic Tests Coverage, Personal Accident Insurance'
#  'Preventive Services, Dental Exams and Cleanings, Collision Coverage, Medical Equipment and Supplies'
#  'Critical Illness Coverage, Vision Exams and Eyewear, Maternity and Newborn Care, Home Healthcare Services, Natural Disaster Protection'
#  'Mental Health Coverage, Emergency Room Visits, Prescription Drugs Coverage, Towing and Labor Coverage'
#  'Surgery Coverage, Pediatric Services, Speech Therapy Coverage, Comprehensive Coverage'
#  'Preventive Services, Occupational Therapy Coverage, Dental Exams and Cleanings, Rental Car Reimbursement'
#  'Critical Illness Coverage, Vision Exams and Eyewear, Prescription Drugs Coverage, Chiropractic Care Coverage, Liability Coverage'
#  'Mental Health Coverage, Emergency Room Visits, Maternity and Newborn Care, Diagnostic Tests Coverage, Collision Coverage'
#  'Surgery Coverage, Pediatric Services, Preventive Services, Occupational Therapy Coverage'
#  'Critical Illness Coverage, Mental Health Coverage, Dental Exams and Cleanings, Vision Exams and Eyewear, Prescription Drugs Coverage, Roadside Assistance, Comprehensive Coverage'
#  'Hospitalization Coverage, Surgery Coverage, Emergency Room Visits, Maternity and Newborn Care, Pediatric Services, Personal Accident Insurance, Collision Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Laboratory Services, Diagnostic Tests Coverage, Preventive Services, Comprehensive Coverage'
#  'Maternity and Newborn Care, Pediatric Services, Natural Disaster Protection, Gap Insurance'
#  'Prescription Drugs Coverage, Collision Coverage, New Car Replacement Coverage'
#  'Vision Exams and Eyewear, Personal Accident Insurance, Roadside Assistance, Towing and Labor Coverage'
#  'Preventive Services, Mechanical Breakdown Insurance, Liability Coverage'
#  'Chiropractic Care Coverage, Liability Coverage, Sound System Coverage'
#  'Critical Illness Coverage, Mental Health Coverage, Roadside Assistance'
#  'Dental Exams and Cleanings, Vision Exams and Eyewear, Personal Accident Insurance'
#  'Prescription Drugs Coverage, Hospitalization Coverage, Rental Car Reimbursement'
#  'Surgery Coverage, Emergency Room Visits, Modified Parts Coverage'
#  'Physical Therapy Coverage, Occupational Therapy Coverage, Comprehensive Coverage'
#  'Speech Therapy Coverage, Chiropractic Care Coverage, Collision Coverage'
#  'Home Healthcare Services, Hospice Care Coverage, Liability Coverage'
#  'Medical Equipment and Supplies, Laboratory Services, Uninsured/Underinsured Motorist Coverage'
#  'Diagnostic Tests Coverage, Preventive Services, Towing and Labor Coverage'
#  'Critical Illness Coverage, Dental Exams and Cleanings, Gap Insurance'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, New Car Replacement Coverage'
#  'Hospitalization Coverage, Surgery Coverage, Loss of Use Coverage'
#  'Emergency Room Visits, Maternity and Newborn Care, Key Replacement Coverage'
#  'Pediatric Services, Physical Therapy Coverage, Mechanical Breakdown Insurance'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Glass Coverage'
#  'Chiropractic Care Coverage, Home Healthcare Services, Sound System Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Roadside Assistance'
#  'Laboratory Services, Diagnostic Tests Coverage, Personal Accident Insurance'
#  'Preventive Services, Critical Illness Coverage, Rental Car Reimbursement'
#  'Mental Health Coverage, Dental Exams and Cleanings, Modified Parts Coverage'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, Natural Disaster Protection'
#  'Hospitalization Coverage, Surgery Coverage, Comprehensive Coverage'
#  'Emergency Room Visits, Maternity and Newborn Care, Collision Coverage'
#  'Pediatric Services, Physical Therapy Coverage, Liability Coverage'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Uninsured/Underinsured Motorist Coverage'
#  'Chiropractic Care Coverage, Home Healthcare Services, Towing and Labor Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Gap Insurance'
#  'Laboratory Services, Diagnostic Tests Coverage, New Car Replacement Coverage'
#  'Preventive Services, Critical Illness Coverage, Loss of Use Coverage'
#  'Mental Health Coverage, Dental Exams and Cleanings, Key Replacement Coverage'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, Mechanical Breakdown Insurance'
#  'Hospitalization Coverage, Surgery Coverage, Glass Coverage'
#  'Emergency Room Visits, Maternity and Newborn Care, Sound System Coverage'
#  'Pediatric Services, Physical Therapy Coverage, Roadside Assistance'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Personal Accident Insurance'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Modified Parts Coverage'
#  'Laboratory Services, Diagnostic Tests Coverage, Natural Disaster Protection'
#  'Preventive Services, Critical Illness Coverage, Comprehensive Coverage'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, Liability Coverage'
#  'Hospitalization Coverage, Surgery Coverage, Uninsured/Underinsured Motorist Coverage'
#  'Emergency Room Visits, Maternity and Newborn Care, Towing and Labor Coverage'
#  'Pediatric Services, Physical Therapy Coverage, Gap Insurance'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, New Car Replacement Coverage'
#  'Chiropractic Care Coverage, Home Healthcare Services, Loss of Use Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Key Replacement Coverage'
#  'Laboratory Services, Diagnostic Tests Coverage, Mechanical Breakdown Insurance'
#  'Preventive Services, Critical Illness Coverage, Glass Coverage'
#  'Mental Health Coverage, Dental Exams and Cleanings, Sound System Coverage'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, Roadside Assistance'
#  'Hospitalization Coverage, Surgery Coverage, Personal Accident Insurance'
#  'Emergency Room Visits, Maternity and Newborn Care, Rental Car Reimbursement'
#  'Pediatric Services, Physical Therapy Coverage, Modified Parts Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Collision Coverage'
#  'Laboratory Services, Diagnostic Tests Coverage, Liability Coverage'
#  'Preventive Services, Critical Illness Coverage, Uninsured/Underinsured Motorist Coverage'
#  'Mental Health Coverage, Dental Exams and Cleanings, Towing and Labor Coverage'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, Gap Insurance'
#  'Hospitalization Coverage, Surgery Coverage, New Car Replacement Coverage'
#  'Emergency Room Visits, Maternity and Newborn Care, Loss of Use Coverage'
#  'Pediatric Services, Physical Therapy Coverage, Key Replacement Coverage'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Mechanical Breakdown Insurance'
#  'Chiropractic Care Coverage, Home Healthcare Services, Glass Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Sound System Coverage'
#  'Laboratory Services, Diagnostic Tests Coverage, Roadside Assistance'
#  'Preventive Services, Critical Illness Coverage, Personal Accident Insurance'
#  'Mental Health Coverage, Dental Exams and Cleanings, Rental Car Reimbursement'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, Modified Parts Coverage'
#  'Hospitalization Coverage, Surgery Coverage, Natural Disaster Protection'
#  'Pediatric Services, Physical Therapy Coverage, Collision Coverage'
#  'Chiropractic Care Coverage, Home Healthcare Services, Uninsured/Underinsured Motorist Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Towing and Labor Coverage'
#  'Laboratory Services, Diagnostic Tests Coverage, Gap Insurance'
#  'Preventive Services, Critical Illness Coverage, New Car Replacement Coverage'
#  'Mental Health Coverage, Dental Exams and Cleanings, Loss of Use Coverage'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, Key Replacement Coverage'
#  'Hospitalization Coverage, Surgery Coverage, Mechanical Breakdown Insurance'
#  'Emergency Room Visits, Maternity and Newborn Care, Glass Coverage'
#  'Pediatric Services, Physical Therapy Coverage, Sound System Coverage'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Roadside Assistance'
#  'Chiropractic Care Coverage, Home Healthcare Services, Personal Accident Insurance'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Rental Car Reimbursement'
#  'Laboratory Services, Diagnostic Tests Coverage, Modified Parts Coverage'
#  'Preventive Services, Critical Illness Coverage, Natural Disaster Protection'
#  'Mental Health Coverage, Dental Exams and Cleanings, Comprehensive Coverage'
#  'Vision Exams and Eyewear, Prescription Drugs Coverage, Collision Coverage'
#  'Hospitalization Coverage, Surgery Coverage, Liability Coverage'
#  'Emergency Room Visits, Maternity and Newborn Care, Uninsured/Underinsured Motorist Coverage'
#  'Pediatric Services, Physical Therapy Coverage, Towing and Labor Coverage'
#  'Occupational Therapy Coverage, Speech Therapy Coverage, Gap Insurance'
#  'Chiropractic Care Coverage, Home Healthcare Services, New Car Replacement Coverage'
#  'Hospice Care Coverage, Medical Equipment and Supplies, Loss of Use Coverage'
#  'Laboratory Services, Diagnostic Tests Coverage, Key Replacement Coverage'
#  'Preventive Services, Critical Illness Coverage, Mechanical Breakdown Insurance']
#
# Premium_Bin:
#
# ['Extremely High' 'Very Low' 'Very High' 'High' 'Medium' 'Low']
#
# Age_Generation:
#
# ['Silent' 'Gen Z' 'Millennials' 'Gen X' 'Boomers']

# %%
#Check missing value
df.isna().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# Year                    0
# Product                 0
# Premium_Bin             0
# Age_Generation          0
# dtype: int64

# %%
#Drop unnecessary columns
df.drop(['Year', 'Product', 'Premium_Bin', 'Age_Generation', 'id'], axis=1, inplace=True)
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0    Male   76                1            3                   0    1-2 Year
# 1    Male   21                1           11                   1    < 1 Year
# 2  Female   29                1           41                   1    < 1 Year
# 3  Female   24                1           33                   0    < 1 Year
# 4    Male   23                1           11                   0    < 1 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0             No           33536                    26      183         0
# 1             No           28619                   152      203         0
# 2             No           27496                   152       39         0
# 3            Yes            2630                   160      176         0
# 4            Yes           23367                   152      249         0

# %%
numerical_columns = ['Age', 'Region_Code', 'Annual_Premium', 'Policy_Sales_Channel', 'Vintage']

plt.figure(figsize=(20, 5))

for i, col in enumerate(numerical_columns):
    plt.subplot(1, 5, i+1)
    sns.boxplot(y=df[col])
    plt.title(f'Box plot of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Encoding Object**

# %% [markdown]
# **1. Gender**

# %%
df['Gender'] = df['Gender'].map({'Female':1, 'Male':0})
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0       0   76                1            3                   0    1-2 Year
# 1       0   21                1           11                   1    < 1 Year
# 2       1   29                1           41                   1    < 1 Year
# 3       1   24                1           33                   0    < 1 Year
# 4       0   23                1           11                   0    < 1 Year
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0             No           33536                    26      183         0
# 1             No           28619                   152      203         0
# 2             No           27496                   152       39         0
# 3            Yes            2630                   160      176         0
# 4            Yes           23367                   152      249         0

# %% [markdown]
# **2. Vehicle Damage**

# %%
df['Vehicle_Damage'] = df['Vehicle_Damage'].map({'Yes':1, 'No':0})
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age  \
# 0       0   76                1            3                   0    1-2 Year
# 1       0   21                1           11                   1    < 1 Year
# 2       1   29                1           41                   1    < 1 Year
# 3       1   24                1           33                   0    < 1 Year
# 4       0   23                1           11                   0    < 1 Year
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               0           33536                    26      183         0
# 1               0           28619                   152      203         0
# 2               0           27496                   152       39         0
# 3               1            2630                   160      176         0
# 4               1           23367                   152      249         0

# %% [markdown]
# **3.Vehicle Age**

# %%
df['Vehicle_Age'] = df['Vehicle_Age'].map({'1-2 Year':1, '< 1 Year':0, '> 2 Years': 2})
df.head()
# Out:
#    Gender  Age  Driving_License  Region_Code  Previously_Insured  Vehicle_Age  \
# 0       0   76                1            3                   0            1
# 1       0   21                1           11                   1            0
# 2       1   29                1           41                   1            0
# 3       1   24                1           33                   0            0
# 4       0   23                1           11                   0            0
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0               0           33536                    26      183         0
# 1               0           28619                   152      203         0
# 2               0           27496                   152       39         0
# 3               1            2630                   160      176         0
# 4               1           23367                   152      249         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Gender                381109 non-null  int64
#  1   Age                   381109 non-null  int64
#  2   Driving_License       381109 non-null  int64
#  3   Region_Code           381109 non-null  int64
#  4   Previously_Insured    381109 non-null  int64
#  5   Vehicle_Age           381109 non-null  int64
#  6   Vehicle_Damage        381109 non-null  int64
#  7   Annual_Premium        381109 non-null  int64
#  8   Policy_Sales_Channel  381109 non-null  int64
#  9   Vintage               381109 non-null  int64
#  10  Response              381109 non-null  int64
# dtypes: int64(11)
# memory usage: 32.0 MB

# %% [markdown]
# **Feature Engineering and Feature Selection**

# %%
X = df.drop(columns = [ 'Driving_License','Response', 'Region_Code', 'Policy_Sales_Channel', 'Gender', 'Vintage'])
y = df['Response']

# %% [markdown]
# **Model Building**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, test_size = 0.2)

# %% [markdown]
# **SMOTE**

# %%
sm = SMOTE(random_state = 42)
X_train.head()
# Out:
#         Age  Previously_Insured  Vehicle_Age  Vehicle_Damage  Annual_Premium
# 332803   70                   1            1               0           85060
# 116248   21                   1            0               0           30421
# 255005   27                   1            0               0           37387
# 317474   34                   0            2               1           28552
# 344212   40                   0            1               1            2630

# %%
X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)
df['Response'].value_counts()
# Out:
# Response
# 0    334399
# 1     46710
# Name: count, dtype: int64

# %%
# Display the distribution of the target variable in the testing set
print("Testing set distribution:")
print(y_test.value_counts())
# Out:
# Testing set distribution:
# Response
# 0    66892
# 1     9330
# Name: count, dtype: int64

# %%
# Display the distribution of the target variable in the initial dataset
print("Initial dataset distribution:")
print(df['Response'].value_counts())

# Display the distribution of the target variable in the testing set
print("Testing set distribution:")
print(y_test.value_counts())

# Display the distribution of the target variable after SMOTE
print("Training set distribution:")
print(y_train_sm.value_counts())
# Out:
# Initial dataset distribution:
# Response
# 0    334399
# 1     46710
# Name: count, dtype: int64
# Testing set distribution:
# Response
# 0    66892
# 1     9330
# Name: count, dtype: int64
# Training set distribution:
# Response
# 0    267507
# 1    267507
# Name: count, dtype: int64

# %% [markdown]
# **1. Logistic Regression**

# %%
# Logistic Regression model
modelSMOTE_logreg = LogisticRegression()
modelSMOTE_logreg.fit(X_train_sm, y_train_sm)

# Predicting using the Logistic Regression model
y_pred_SMOTE_logreg = modelSMOTE_logreg.predict(X_test)

# Calculating evaluation metrics
acc_logreg = accuracy_score(y_test, y_pred_SMOTE_logreg)
recall_logreg = recall_score(y_test, y_pred_SMOTE_logreg)
prec_logreg = precision_score(y_test, y_pred_SMOTE_logreg)
f1_logreg = f1_score(y_test, y_pred_SMOTE_logreg)

# Printing the classification report
print("--- Logistic Regression ---")
print(classification_report(y_test, y_pred_SMOTE_logreg))

# Compute confusion matrix
cm_smote_log_reg = confusion_matrix(y_test, y_pred_SMOTE_logreg, labels=[1, 0])

# Create DataFrame for confusion matrix
df_smote_logreg = pd.DataFrame(data=cm_smote_log_reg, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame
print(df_smote_logreg)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_smote_logreg, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Logistic Regression')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --- Logistic Regression ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74     66892
#            1       0.25      0.98      0.40      9330
#
#     accuracy                           0.64     76222
#    macro avg       0.62      0.78      0.57     76222
# weighted avg       0.90      0.64      0.70     76222
#
#           Predicted 1  Predicted 0
# Actual 1         9097          233
# Actual 0        27410        39482

# %%
from sklearn.metrics import roc_auc_score, roc_curve

# Calculate ROC AUC
y_prob_logreg = modelSMOTE_logreg.predict_proba(X_test)[:, 1]  # Probabilities for the positive class
roc_auc_logreg = roc_auc_score(y_test, y_prob_logreg)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_logreg)

# Print ROC AUC
print(f"ROC AUC: {roc_auc_logreg:.4f}")

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label='Logistic Regression (AUC = %0.4f)' % roc_auc_logreg)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity
tn, fp, fn, tp = cm_smote_log_reg.ravel()
sensitivity = tp / (tp + fn)  # Recall
specificity = tn / (tn + fp)

# Print Sensitivity and Specificity
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# ROC AUC: 0.8267
# Sensitivity (Recall): 0.5902
# Specificity: 0.9750

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, roc_curve

# Logistic Regression model
modelSMOTE_logreg = LogisticRegression()
modelSMOTE_logreg.fit(X_train_sm, y_train_sm)

# Predicting using the Logistic Regression model
y_pred_SMOTE_logreg = modelSMOTE_logreg.predict(X_test)

# Calculating evaluation metrics
acc_logreg = accuracy_score(y_test, y_pred_SMOTE_logreg)
recall_logreg = recall_score(y_test, y_pred_SMOTE_logreg)
prec_logreg = precision_score(y_test, y_pred_SMOTE_logreg)
f1_logreg = f1_score(y_test, y_pred_SMOTE_logreg)

# Printing the classification report
print("--- Logistic Regression ---")
print(classification_report(y_test, y_pred_SMOTE_logreg))

# Compute confusion matrix
cm_smote_log_reg = confusion_matrix(y_test, y_pred_SMOTE_logreg, labels=[1, 0])

# Create DataFrame for confusion matrix
df_smote_logreg = pd.DataFrame(data=cm_smote_log_reg, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame
print("Confusion Matrix:")
print(df_smote_logreg)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_smote_logreg, annot=True, fmt='d', cmap='Blues', 
            cbar=False, square=True, linewidths=0.5)
plt.title('Confusion Matrix - Logistic Regression')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate ROC AUC
y_prob_logreg = modelSMOTE_logreg.predict_proba(X_test)[:, 1] 
roc_auc_logreg = roc_auc_score(y_test, y_prob_logreg)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_logreg)

# Print ROC AUC
print(f"ROC AUC: {roc_auc_logreg:.4f}")

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label='Logistic Regression (AUC = %0.4f)' % roc_auc_logreg)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity
tn, fp, fn, tp = cm_smote_log_reg.ravel()
sensitivity = tp / (tp + fn) 
specificity = tn / (tn + fp)

# Print Sensitivity and Specificity
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --- Logistic Regression ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74     66892
#            1       0.25      0.98      0.40      9330
#
#     accuracy                           0.64     76222
#    macro avg       0.62      0.78      0.57     76222
# weighted avg       0.90      0.64      0.70     76222
#
# Confusion Matrix:
#           Predicted 1  Predicted 0
# Actual 1         9097          233
# Actual 0        27410        39482
# ROC AUC: 0.8267
# Sensitivity (Recall): 0.5902
# Specificity: 0.9750

# %%
# Logistic Regression model
modelSMOTE_logreg = LogisticRegression()
modelSMOTE_logreg.fit(X_train_sm, y_train_sm)

# Predicting using the Logistic Regression model
y_pred_SMOTE_logreg = modelSMOTE_logreg.predict(X_test)

# Calculating evaluation metrics
acc_logreg = accuracy_score(y_test, y_pred_SMOTE_logreg)
recall_logreg = recall_score(y_test, y_pred_SMOTE_logreg)
prec_logreg = precision_score(y_test, y_pred_SMOTE_logreg)
f1_logreg = f1_score(y_test, y_pred_SMOTE_logreg)

# Printing the classification report
print("--- Logistic Regression ---")
print(classification_report(y_test, y_pred_SMOTE_logreg))

# Compute confusion matrix
cm_smote_log_reg = confusion_matrix(y_test, y_pred_SMOTE_logreg, labels=[1, 0])

# Create DataFrame for confusion matrix
df_smote_logreg = pd.DataFrame(data=cm_smote_log_reg, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame
print(df_smote_logreg)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_smote_logreg, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Logistic Regression')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate ROC AUC
y_prob_logreg = modelSMOTE_logreg.predict_proba(X_test)[:, 1]  # Probabilities for the positive class
roc_auc_logreg = roc_auc_score(y_test, y_prob_logreg)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_logreg)

# Print ROC AUC
print(f"ROC AUC: {roc_auc_logreg:.4f}")

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label='Logistic Regression (AUC = %0.4f)' % roc_auc_logreg)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity
tn, fp, fn, tp = cm_smote_log_reg.ravel()
sensitivity = tp / (tp + fn)  # Recall
specificity = tn / (tn + fp)

# Print Sensitivity and Specificity
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# --- Logistic Regression ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74     66892
#            1       0.25      0.98      0.40      9330
#
#     accuracy                           0.64     76222
#    macro avg       0.62      0.78      0.57     76222
# weighted avg       0.90      0.64      0.70     76222
#
#           Predicted 1  Predicted 0
# Actual 1         9097          233
# Actual 0        27410        39482
# ROC AUC: 0.8267
# Sensitivity (Recall): 0.5902
# Specificity: 0.9750

# %% [markdown]
# **2. KNN Classifier**

# %%
# KNN Classifier model
modelSMOTE_KNN = KNeighborsClassifier()
modelSMOTE_KNN.fit(X_train_sm, y_train_sm)

# Predicting using the KNN Classifier model
y_pred_SMOTE_KNN = modelSMOTE_KNN.predict(X_test)

# Calculating evaluation metrics for KNN Classifier
acc_KNN = accuracy_score(y_test, y_pred_SMOTE_KNN)
recall_KNN = recall_score(y_test, y_pred_SMOTE_KNN)
prec_KNN = precision_score(y_test, y_pred_SMOTE_KNN)
f1_KNN = f1_score(y_test, y_pred_SMOTE_KNN)

# Printing the classification report for KNN Classifier
print("--- KNN Classifier ---")
print(classification_report(y_test, y_pred_SMOTE_KNN))

# Compute confusion matrix for KNN Classifier
cm_smote_KNN = confusion_matrix(y_test, y_pred_SMOTE_KNN, labels=[1, 0])

# Create DataFrame for confusion matrix for KNN Classifier
df_smote_KNN = pd.DataFrame(data=cm_smote_KNN, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame for KNN Classifier
print(df_smote_KNN)

# Plotting the heatmap for KNN Classifier
plt.figure(figsize=(8, 6))
sns.heatmap(df_smote_KNN, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - KNN Classifier with SMOTE')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate ROC AUC for KNN Classifier
y_prob_KNN = modelSMOTE_KNN.predict_proba(X_test)[:, 1]  # Probabilities for the positive class
roc_auc_KNN = roc_auc_score(y_test, y_prob_KNN)

# Calculate ROC curve for KNN Classifier
fpr_KNN, tpr_KNN, thresholds_KNN = roc_curve(y_test, y_prob_KNN)

# Print ROC AUC for KNN Classifier
print(f"ROC AUC: {roc_auc_KNN:.4f}")

# Plot ROC Curve for KNN Classifier
plt.figure(figsize=(8, 6))
plt.plot(fpr_KNN, tpr_KNN, marker='.', label='KNN Classifier (AUC = %0.4f)' % roc_auc_KNN)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - KNN Classifier')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity for KNN Classifier
tn_KNN, fp_KNN, fn_KNN, tp_KNN = cm_smote_KNN.ravel()
sensitivity_KNN = tp_KNN / (tp_KNN + fn_KNN)  # Recall
specificity_KNN = tn_KNN / (tn_KNN + fp_KNN)

# Print Sensitivity and Specificity for KNN Classifier
print(f"Sensitivity (Recall): {sensitivity_KNN:.4f}")
print(f"Specificity: {specificity_KNN:.4f}")
# Out:
# --- KNN Classifier ---
#               precision    recall  f1-score   support
#
#            0       0.90      0.76      0.82     66892
#            1       0.19      0.41      0.26      9330
#
#     accuracy                           0.72     76222
#    macro avg       0.55      0.59      0.54     76222
# weighted avg       0.82      0.72      0.76     76222
#
#           Predicted 1  Predicted 0
# Actual 1         3839         5491
# Actual 0        16114        50778
# ROC AUC: 0.6396
# Sensitivity (Recall): 0.7591
# Specificity: 0.4115

# %% [markdown]
# **3. Decision Tree**

# %%
# Decision Tree Classifier model
modelSMOTE_DT = DecisionTreeClassifier()
modelSMOTE_DT.fit(X_train_sm, y_train_sm)

# Predicting using the Decision Tree Classifier model
y_pred_SMOTE_DT = modelSMOTE_DT.predict(X_test)

# Calculating evaluation metrics
acc_DT = accuracy_score(y_test, y_pred_SMOTE_DT)
recall_DT = recall_score(y_test, y_pred_SMOTE_DT)
prec_DT = precision_score(y_test, y_pred_SMOTE_DT)
f1_DT = f1_score(y_test, y_pred_SMOTE_DT)

# Printing the classification report
print("--- Decision Tree Classifier ---")
print(classification_report(y_test, y_pred_SMOTE_DT))

# Compute confusion matrix
cm_smote_DT = confusion_matrix(y_test, y_pred_SMOTE_DT, labels=[1, 0])

# Create DataFrame for confusion matrix
df_smote_DT = pd.DataFrame(data=cm_smote_DT, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame
print(df_smote_DT)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_smote_DT, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix - Decision Tree Classifier')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate ROC AUC
y_prob_DT = modelSMOTE_DT.predict_proba(X_test)[:, 1]  # Probabilities for the positive class
roc_auc_DT = roc_auc_score(y_test, y_prob_DT)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_DT)

# Print ROC AUC
print(f"ROC AUC: {roc_auc_DT:.4f}")

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label='Decision Tree Classifier (AUC = %0.4f)' % roc_auc_DT)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Decision Tree Classifier')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity
tn, fp, fn, tp = cm_smote_DT.ravel()
sensitivity = tp / (tp + fn)  # Recall
specificity = tn / (tn + fp)

# Print Sensitivity and Specificity
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# --- Decision Tree Classifier ---
#               precision    recall  f1-score   support
#
#            0       0.93      0.78      0.85     66892
#            1       0.27      0.57      0.36      9330
#
#     accuracy                           0.75     76222
#    macro avg       0.60      0.68      0.61     76222
# weighted avg       0.85      0.75      0.79     76222
#
#           Predicted 1  Predicted 0
# Actual 1         5355         3975
# Actual 0        14761        52131
# ROC AUC: 0.6833
# Sensitivity (Recall): 0.7793
# Specificity: 0.5740

# %% [markdown]
# **4. Random Forest Classifier**

# %%
# Random Forest Classifier model
modelSMOTERF = RandomForestClassifier()
modelSMOTERF.fit(X_train_sm, y_train_sm)

# Predicting using the Random Forest Classifier model
y_pred_SMOTE_RF = modelSMOTERF.predict(X_test)

# Calculating evaluation metrics
acc_RF = accuracy_score(y_test, y_pred_SMOTE_RF)
prec_RF = precision_score(y_test, y_pred_SMOTE_RF)
rec_RF = recall_score(y_test, y_pred_SMOTE_RF)
f1_RF = f1_score(y_test, y_pred_SMOTE_RF)

# Printing the classification report
print("--- Random Forest Classifier ---")
print(classification_report(y_test, y_pred_SMOTE_RF))

# Compute confusion matrix
cm_RF = confusion_matrix(y_test, y_pred_SMOTE_RF, labels=[1, 0])

# Create DataFrame for confusion matrix
df_RF = pd.DataFrame(data=cm_RF, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame
print(df_RF)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_RF, annot=True, cmap='Blues', fmt='d')
plt.title('Confusion Matrix - Random Forest Classifier')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate ROC AUC
y_prob_RF = modelSMOTERF.predict_proba(X_test)[:, 1]  # Probabilities for the positive class
roc_auc_RF = roc_auc_score(y_test, y_prob_RF)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_RF)

# Print ROC AUC
print(f"ROC AUC: {roc_auc_RF:.4f}")

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label='Random Forest Classifier (AUC = %0.4f)' % roc_auc_RF)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Random Forest Classifier')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity
tn, fp, fn, tp = cm_RF.ravel()
sensitivity = tp / (tp + fn)  # Recall
specificity = tn / (tn + fp)

# Print Sensitivity and Specificity
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# --- Random Forest Classifier ---
#               precision    recall  f1-score   support
#
#            0       0.94      0.76      0.84     66892
#            1       0.27      0.63      0.37      9330
#
#     accuracy                           0.74     76222
#    macro avg       0.60      0.69      0.61     76222
# weighted avg       0.85      0.74      0.78     76222
#
#           Predicted 1  Predicted 0
# Actual 1         5858         3472
# Actual 0        16126        50766
# ROC AUC: 0.7969
# Sensitivity (Recall): 0.7589
# Specificity: 0.6279

# %% [markdown]
# **Compare 4 models - Training**

# %%
# Initialize models
models = {
    'Logistic Regression': LogisticRegression(),
    'KNN Classifier': KNeighborsClassifier(),
    'Decision Tree Classifier': DecisionTreeClassifier(),
    'Random Forest Classifier': RandomForestClassifier()
}

# Dictionary to store evaluation metrics
metrics_summary = {
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1-Score': []
}

# Iterate through each model
for model_name, model in models.items():
    # Apply SMOTE to balance the dataset
    sm = SMOTE(random_state=42)
    X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)
    
    # Train the model
    model.fit(X_train_sm, y_train_sm)
    
    # Predict using the model
    y_pred = model.predict(X_test)
    
    # Calculate evaluation metrics
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    
    # Store metrics in summary dictionary
    metrics_summary['Model'].append(model_name)
    metrics_summary['Accuracy'].append(acc)
    metrics_summary['Precision'].append(prec)
    metrics_summary['Recall'].append(rec)
    metrics_summary['F1-Score'].append(f1)

# Create a DataFrame for the summary
df_summary = pd.DataFrame(metrics_summary)

# Print the summary table
print("--- Summary of Model Metrics ---")
print(df_summary)
# Out:
# --- Summary of Model Metrics ---
#                       Model  Accuracy  Precision    Recall  F1-Score
# 0       Logistic Regression  0.644801   0.251415  0.961736  0.398623
# 1            KNN Classifier  0.716552   0.192402  0.411468  0.262200
# 2  Decision Tree Classifier  0.754297   0.266242  0.573633  0.363686
# 3  Random Forest Classifier  0.742988   0.266521  0.627653  0.374161

# %%
# Convert confusion matrices to DataFrames
df_cm_logreg = pd.DataFrame(data=cm_smote_log_reg, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
df_cm_KNN = pd.DataFrame(data=cm_smote_KNN, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
df_cm_RF = pd.DataFrame(data=cm_RF, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
df_cm_DT = pd.DataFrame(data=cm_smote_DT, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Combine DataFrames into one DataFrame with multi-level columns
df_cm_combined = pd.concat(
    [df_cm_logreg.add_suffix(' (LogReg)'), df_cm_KNN.add_suffix(' (KNN)'), df_cm_RF.add_suffix(' (RF)'), df_cm_DT.add_suffix(' (DT)')],
    axis=1
)

# Print the combined DataFrame
print("Confusion Matrix Comparison")
print(df_cm_combined)
# Out:
# Confusion Matrix Comparison
#           Predicted 1 (LogReg)  Predicted 0 (LogReg)  Predicted 1 (KNN)  \
# Actual 1                  8973                   357               3839
# Actual 0                 26717                 40175              16114
#
#           Predicted 0 (KNN)  Predicted 1 (RF)  Predicted 0 (RF)  \
# Actual 1               5491              5860              3470
# Actual 0              50778             16119             50773
#
#           Predicted 1 (DT)  Predicted 0 (DT)
# Actual 1              5352              3978
# Actual 0             14771             52121

# %%
# Logistic Regression
modelSMOTE_logreg = LogisticRegression()
modelSMOTE_logreg.fit(X_train_sm, y_train_sm)
y_pred_SMOTE_logreg = modelSMOTE_logreg.predict(X_test)
cm_smote_log_reg = confusion_matrix(y_test, y_pred_SMOTE_logreg, labels=[1, 0])
df_cm_logreg = pd.DataFrame(data=cm_smote_log_reg, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
y_prob_logreg = modelSMOTE_logreg.predict_proba(X_test)[:, 1]
roc_auc_logreg = roc_auc_score(y_test, y_prob_logreg)
fpr_logreg, tpr_logreg, _ = roc_curve(y_test, y_prob_logreg)
tn_logreg, fp_logreg, fn_logreg, tp_logreg = cm_smote_log_reg.ravel()
sensitivity_logreg = tp_logreg / (tp_logreg + fn_logreg)
specificity_logreg = tn_logreg / (tn_logreg + fp_logreg)

# KNN Classifier
modelSMOTE_KNN = KNeighborsClassifier()
modelSMOTE_KNN.fit(X_train_sm, y_train_sm)
y_pred_SMOTE_KNN = modelSMOTE_KNN.predict(X_test)
cm_smote_KNN = confusion_matrix(y_test, y_pred_SMOTE_KNN, labels=[1, 0])
df_cm_KNN = pd.DataFrame(data=cm_smote_KNN, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
y_prob_KNN = modelSMOTE_KNN.predict_proba(X_test)[:, 1]
roc_auc_KNN = roc_auc_score(y_test, y_prob_KNN)
fpr_KNN, tpr_KNN, _ = roc_curve(y_test, y_prob_KNN)
tn_KNN, fp_KNN, fn_KNN, tp_KNN = cm_smote_KNN.ravel()
sensitivity_KNN = tp_KNN / (tp_KNN + fn_KNN)
specificity_KNN = tn_KNN / (tn_KNN + fp_KNN)

# Random Forest Classifier
modelSMOTE_RF = RandomForestClassifier()
modelSMOTE_RF.fit(X_train_sm, y_train_sm)
y_pred_SMOTE_RF = modelSMOTE_RF.predict(X_test)
cm_RF = confusion_matrix(y_test, y_pred_SMOTE_RF, labels=[1, 0])
df_RF = pd.DataFrame(data=cm_RF, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
y_prob_RF = modelSMOTE_RF.predict_proba(X_test)[:, 1]
roc_auc_RF = roc_auc_score(y_test, y_prob_RF)
fpr_RF, tpr_RF, _ = roc_curve(y_test, y_prob_RF)
tn_RF, fp_RF, fn_RF, tp_RF = cm_RF.ravel()
sensitivity_RF = tp_RF / (tp_RF + fn_RF)
specificity_RF = tn_RF / (tn_RF + fp_RF)

# Decision Tree Classifier
modelSMOTE_DT = DecisionTreeClassifier()
modelSMOTE_DT.fit(X_train_sm, y_train_sm)
y_pred_SMOTE_DT = modelSMOTE_DT.predict(X_test)
cm_smote_DT = confusion_matrix(y_test, y_pred_SMOTE_DT, labels=[1, 0])
df_smote_DT = pd.DataFrame(data=cm_smote_DT, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
y_prob_DT = modelSMOTE_DT.predict_proba(X_test)[:, 1]
roc_auc_DT = roc_auc_score(y_test, y_prob_DT)
fpr_DT, tpr_DT, _ = roc_curve(y_test, y_prob_DT)
tn_DT, fp_DT, fn_DT, tp_DT = cm_smote_DT.ravel()
sensitivity_DT = tp_DT / (tp_DT + fn_DT)
specificity_DT = tn_DT / (tn_DT + fp_DT)

# Create a DataFrame to compare Sensitivity, Specificity, and ROC AUC
metrics_df = pd.DataFrame({
    'Model': ['Logistic Regression', 'KNN Classifier', 'Random Forest Classifier', 'Decision Tree Classifier'],
    'Sensitivity (Recall)': [sensitivity_logreg, sensitivity_KNN, sensitivity_RF, sensitivity_DT],
    'Specificity': [specificity_logreg, specificity_KNN, specificity_RF, specificity_DT],
    'ROC AUC': [roc_auc_logreg, roc_auc_KNN, roc_auc_RF, roc_auc_DT]
})

# Print the comparison table
print("Model Comparison Summary")
print(metrics_df)
# Out:
# Model Comparison Summary
#                       Model  Sensitivity (Recall)  Specificity   ROC AUC
# 0       Logistic Regression              0.600595     0.961736  0.818068
# 1            KNN Classifier              0.759104     0.411468  0.639635
# 2  Random Forest Classifier              0.759134     0.627546  0.797186
# 3  Decision Tree Classifier              0.779137     0.572562  0.682541

# %%
logreg_tuning = LogisticRegression()
param_logreg = {'C': [1, 0.5, 0.1, 5, 9],
               'penalty':['l1','l2', 'elasticnet']}

model_logreg_tuned = GridSearchCV(estimator = logreg_tuning, param_grid = param_logreg, cv = 3, n_jobs = -1 , verbose = 1, scoring = 'recall')

model_logreg_tuned.fit(X_train_sm, y_train_sm)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 30 fits failed out of a total of 45.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan 0.96917838        nan        nan 0.96917838        nan
#         nan 0.96917838        nan        nan 0.96917838        nan
#         nan 0.96917838        nan]
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# GridSearchCV(cv=3, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [1, 0.5, 0.1, 5, 9],
#                          'penalty': ['l1', 'l2', 'elasticnet']},
#              scoring='recall', verbose=1)

# %%
# Predicting using the best Logistic Regression model
y_pred_logreg = model_logreg_tuned.predict(X_test)

# Calculating evaluation metrics
acc_logreg = accuracy_score(y_test, y_pred_logreg)
recall_logreg = recall_score(y_test, y_pred_logreg)
prec_logreg = precision_score(y_test, y_pred_logreg)
f1_logreg = f1_score(y_test, y_pred_logreg)

# Printing the classification report
print("--- Logistic Regression ---")
print(classification_report(y_test, y_pred_logreg))

# Compute confusion matrix
cm_logreg = confusion_matrix(y_test, y_pred_logreg, labels=[1, 0])

# Create DataFrame for confusion matrix
df_logreg = pd.DataFrame(data=cm_logreg, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame
print("Confusion Matrix:")
print(df_logreg)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_logreg, annot=True, fmt='d', cmap='Blues', cbar=False, square=True, linewidths=0.5)
plt.title('Confusion Matrix - Logistic Regression')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate ROC AUC
y_prob_logreg = model_logreg_tuned.predict_proba(X_test)[:, 1]
roc_auc_logreg = roc_auc_score(y_test, y_prob_logreg)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_logreg)

# Print ROC AUC
print(f"ROC AUC: {roc_auc_logreg:.4f}")

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label='Logistic Regression (AUC = %0.4f)' % roc_auc_logreg)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity
tn, fp, fn, tp = cm_logreg.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Print Sensitivity and Specificity
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# --- Logistic Regression ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74     66892
#            1       0.25      0.98      0.40      9330
#
#     accuracy                           0.64     76222
#    macro avg       0.62      0.78      0.57     76222
# weighted avg       0.90      0.64      0.70     76222
#
# Confusion Matrix:
#           Predicted 1  Predicted 0
# Actual 1         9097          233
# Actual 0        27410        39482
# ROC AUC: 0.8267
# Sensitivity (Recall): 0.5902
# Specificity: 0.9750

# %% [markdown]
# KNN Tuning

# %%
# Define parameter grid for KNN
param_grid_knn = {
    'n_neighbors': [5, 7, 9],
    'weights': ['uniform', 'distance'],
    'p': [1, 2]
}

# Perform GridSearchCV for KNN
grid_knn = GridSearchCV(KNeighborsClassifier(), param_grid_knn, cv=5, scoring='accuracy')
grid_knn.fit(X_train_sm, y_train_sm)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [5, 7, 9], 'p': [1, 2],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
# Best parameters and model
model_knn_tuned = grid_knn.best_estimator_

# Predicting using the best KNN model
y_pred_knn = model_knn_tuned.predict(X_test)

# Calculating evaluation metrics
acc_knn = accuracy_score(y_test, y_pred_knn)
recall_knn = recall_score(y_test, y_pred_knn)
prec_knn = precision_score(y_test, y_pred_knn)
f1_knn = f1_score(y_test, y_pred_knn)

# Printing the classification report
print("--- KNN Classifier ---")
print(classification_report(y_test, y_pred_knn))

# Compute confusion matrix
cm_knn = confusion_matrix(y_test, y_pred_knn, labels=[1, 0])

# Create DataFrame for confusion matrix
df_knn = pd.DataFrame(data=cm_knn, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame
print("Confusion Matrix:")
print(df_knn)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_knn, annot=True, fmt='d', cmap='Blues', cbar=False, square=True, linewidths=0.5)
plt.title('Confusion Matrix - KNN Classifier')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate ROC AUC
y_prob_knn = model_knn_tuned.predict_proba(X_test)[:, 1]
roc_auc_knn = roc_auc_score(y_test, y_prob_knn)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_knn)

# Print ROC AUC
print(f"ROC AUC: {roc_auc_knn:.4f}")

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label='KNN Classifier (AUC = %0.4f)' % roc_auc_knn)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - KNN Classifier')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity
tn, fp, fn, tp = cm_knn.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Print Sensitivity and Specificity
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# --- KNN Classifier ---
#               precision    recall  f1-score   support
#
#            0       0.91      0.79      0.84     66892
#            1       0.22      0.42      0.29      9330
#
#     accuracy                           0.74     76222
#    macro avg       0.56      0.61      0.57     76222
# weighted avg       0.82      0.74      0.78     76222
#
# Confusion Matrix:
#           Predicted 1  Predicted 0
# Actual 1         3954         5376
# Actual 0        14078        52814
# ROC AUC: 0.6752
# Sensitivity (Recall): 0.7895
# Specificity: 0.4238

# %% [markdown]
# Decision Tree

# %%
# Define parameter grid for Decision Tree
param_grid_dt = {
    'max_depth': [None, 4, 9, 15, 20, 50],
    'min_samples_leaf': [1, 4, 0.1, 2, 10],
    'max_features': [None, 0.2, 0.8, 2.0],
    'min_samples_split': [2, 9, 15, 25]
}

# Perform GridSearchCV for Decision Tree
grid_dt = GridSearchCV(DecisionTreeClassifier(), param_grid_dt, cv=5, scoring='accuracy')
grid_dt.fit(X_train_sm, y_train_sm)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 600 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 2.0 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.81896549 0.81207409 0.81016199 0.80779382 0.80463316 0.8050238
#  0.80529482 0.80474157 0.77816282 0.77816282 0.77816282 0.77816282
#  0.80702749 0.8095078  0.80892277 0.8074929  0.80085195 0.80082765
#  0.80087625 0.80115662 0.80677142 0.79814174 0.79579788 0.79553246
#  0.78548599 0.78694764 0.78933076 0.78940178 0.7340276  0.74121409
#  0.69269393 0.74047973 0.78929711 0.79113444 0.79192882 0.79359046
#  0.78631215 0.78806723 0.78907655 0.78743922 0.80959004 0.80098466
#  0.79924451 0.79805763 0.78946159 0.79065595 0.79240731 0.79376803
#  0.77122096 0.77816282 0.77189197 0.77077981 0.79244843 0.7955904
#  0.79597357 0.7973698  0.7925531  0.79189517 0.79230264 0.79363158
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.78985036 0.78985036 0.78985036 0.78985036
#  0.78984849 0.78984849 0.78984849 0.78984849 0.77816282 0.77816282
#  0.77816282 0.77816282 0.78985036 0.78985036 0.78985036 0.78985036
#  0.78984849 0.78984849 0.78984849 0.78984849 0.78432339 0.75472048
#  0.78080949 0.77080784 0.75686996 0.77814039 0.76032595 0.75685687
#  0.7585054  0.76687713 0.72322603 0.65971169 0.75198784 0.78074034
#  0.74009265 0.76671269 0.74902343 0.77632923 0.76318362 0.75390172
#  0.78984849 0.78975878 0.78423744 0.78985036 0.78984849 0.78984849
#  0.78657569 0.78984849 0.77392365 0.77448068 0.77386013 0.77079667
#  0.78985036 0.78984849 0.78657756 0.79029708 0.78984849 0.78984849
#  0.7897999  0.78855881        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.79746512 0.7974726
#  0.7974726  0.79748381 0.79749316 0.79749316 0.79749316 0.79749877
#  0.77816282 0.77816282 0.77816282 0.77816282 0.7975025  0.79750998
#  0.79750811 0.79751372 0.7974726  0.7974726  0.7974726  0.79747821
#  0.79303534 0.79258862 0.79333252 0.79468763 0.79394185 0.79279795
#  0.78341129 0.78503742 0.74486091 0.73153421 0.7160671  0.71291942
#  0.79179237 0.79130828 0.79274376 0.79260356 0.79216246 0.79347832
#  0.79614926 0.79212882 0.79645954 0.79701654 0.79669692 0.79783707
#  0.79711746 0.7970128  0.79712307 0.79735484 0.77383584 0.77395919
#  0.77753667 0.77360406 0.79647262 0.79710812 0.79665767 0.79686701
#  0.79691747 0.79682776 0.79708756 0.79692869        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.80202575 0.80188744 0.80173978 0.80132857 0.8017809  0.80180519
#  0.80169866 0.80135287 0.77816282 0.77816282 0.77816282 0.77816282
#  0.80202388 0.80193416 0.80181828 0.80144446 0.80132483 0.80132297
#  0.80133231 0.80120521 0.80089307 0.79988375 0.80026505 0.80012487
#  0.79912489 0.79922022 0.79902957 0.79921274 0.74902903 0.69590505
#  0.70544707 0.73197529 0.79943143 0.80073046 0.79997347 0.79938844
#  0.79922021 0.79904452 0.79739597 0.79832678 0.80152109 0.80130801
#  0.80075476 0.80082391 0.80097344 0.80118091 0.80119026 0.80069494
#  0.77766937 0.77816282 0.7753143  0.77385453 0.80163324 0.80121642
#  0.80076784 0.80072485 0.80073233 0.8005828  0.80036037 0.80067625
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.80775644 0.80714711 0.80642937 0.805278
#  0.80632096 0.80633405 0.80588359 0.80486306 0.77816282 0.77816282
#  0.77816282 0.77816282 0.80722748 0.80700319 0.80639199 0.8053023
#  0.80419392 0.80417336 0.80418644 0.80393785 0.80484063 0.80429672
#  0.80271171 0.80186688 0.80138839 0.80110241 0.80008935 0.79987254
#  0.69392398 0.72227091 0.70776082 0.75594098 0.80316404 0.80286311
#  0.80108745 0.80155474 0.79815669 0.79873425 0.79911181 0.79912864
#  0.80631349 0.80558267 0.80455092 0.80320516 0.80433597 0.80399766
#  0.80362197 0.80310423 0.77061347 0.77439283 0.77763012 0.77079667
#  0.80567799 0.80500511 0.8042612  0.80418271 0.8024164  0.80239584
#  0.80199585 0.80166875        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.81980285 0.81364227
#  0.81136569 0.80884987 0.80691721 0.80723309 0.80697515 0.80613779
#  0.77816282 0.77816282 0.77816282 0.77816282 0.80997133 0.8112199
#  0.81010965 0.80843867 0.80210986 0.80208743 0.80212108 0.80226313
#  0.80740318 0.79859406 0.79721279 0.79596796 0.78626728 0.78781677
#  0.78894946 0.79139986 0.74153383 0.77054992 0.6939725  0.72342789
#  0.79109519 0.79302038 0.79398484 0.7943867  0.78981672 0.78922982
#  0.78948963 0.79004849 0.81052646 0.80167249 0.80082204 0.79922208
#  0.79171761 0.79229142 0.7932615  0.79443156 0.77684697 0.77480777
#  0.77421713 0.77684697 0.79444277 0.79717915 0.79745951 0.79812118
#  0.79260357 0.79275123 0.7925232  0.79400353        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [None, 4, 9, 15, 20, 50],
#                          'max_features': [None, 0.2, 0.8, 2.0],
#                          'min_samples_leaf': [1, 4, 0.1, 2, 10],
#                          'min_samples_split': [2, 9, 15, 25]},
#              scoring='accuracy')

# %%
# Best parameters and model
model_dt_tuned = grid_dt.best_estimator_

# Predicting using the best Decision Tree model
y_pred_dt = model_dt_tuned.predict(X_test)

# Calculating evaluation metrics
acc_dt = accuracy_score(y_test, y_pred_dt)
recall_dt = recall_score(y_test, y_pred_dt)
prec_dt = precision_score(y_test, y_pred_dt)
f1_dt = f1_score(y_test, y_pred_dt)

# Printing the classification report
print("--- Decision Tree ---")
print(classification_report(y_test, y_pred_dt))

# Compute confusion matrix
cm_dt = confusion_matrix(y_test, y_pred_dt, labels=[1, 0])

# Create DataFrame for confusion matrix
df_dt = pd.DataFrame(data=cm_dt, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame
print("Confusion Matrix:")
print(df_dt)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_dt, annot=True, fmt='d', cmap='Blues', cbar=False, square=True, linewidths=0.5)
plt.title('Confusion Matrix - Decision Tree')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate ROC AUC
y_prob_dt = model_dt_tuned.predict_proba(X_test)[:, 1]
roc_auc_dt = roc_auc_score(y_test, y_prob_dt)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_dt)

# Print ROC AUC
print(f"ROC AUC: {roc_auc_dt:.4f}")

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label='Decision Tree (AUC = %0.4f)' % roc_auc_dt)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Decision Tree')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity
tn, fp, fn, tp = cm_dt.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Print Sensitivity and Specificity
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# --- Decision Tree ---
#               precision    recall  f1-score   support
#
#            0       0.93      0.77      0.84     66892
#            1       0.27      0.62      0.37      9330
#
#     accuracy                           0.75     76222
#    macro avg       0.60      0.69      0.61     76222
# weighted avg       0.85      0.75      0.78     76222
#
# Confusion Matrix:
#           Predicted 1  Predicted 0
# Actual 1         5754         3576
# Actual 0        15707        51185
# ROC AUC: 0.6991
# Sensitivity (Recall): 0.7652
# Specificity: 0.6167

# %% [markdown]
# Random Forest

# %%
RF_tuning = RandomForestClassifier()
param_DT =  {
    "n_estimators":[100,500,1000],
    "max_depth": [None, 4,6,8],
    "min_samples_leaf": [1,0.06,3,5],
    "min_samples_split" : [2,9,15,25],
    "max_features" : ['auto','sqrt', 'log2'],
    "criterion": ['gini', 'entropy']}
model_RF_tuned = RandomizedSearchCV(estimator=RF_tuning, param_distributions=param_DT,scoring = 'recall', verbose = 1, n_jobs = -1,cv = 3)
model_RF_tuned.fit(X_train_sm,y_train_sm)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 9 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.90571088        nan 0.90921359        nan 0.89960263        nan
#  0.89701952 0.90707159 0.9019764  0.90178575]
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 4, 6, 8],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 0.06, 3, 5],
#                                         'min_samples_split': [2, 9, 15, 25],
#                                         'n_estimators': [100, 500, 1000]},
#                    scoring='recall', verbose=1)

# %%
# Define parameter grid for Random Forest
param_RF = {
    'n_estimators': [100, 500, 1000],
    'max_depth': [None, 4, 6, 8],
    'min_samples_leaf': [1, 0.06, 3, 5],
    'min_samples_split': [2, 9, 15, 25],
    'max_features': ['auto', 'sqrt', 'log2'],
    'criterion': ['gini', 'entropy']
}

# Perform RandomizedSearchCV for Random Forest
RF_tuning = RandomForestClassifier()
model_RF_tuned = RandomizedSearchCV(estimator=RF_tuning, param_distributions=param_RF, scoring='recall', verbose=1, n_jobs=-1, cv=3)
model_RF_tuned.fit(X_train_sm, y_train_sm)

# %%
# Best parameters and model
best_rf = model_RF_tuned.best_estimator_

# Predicting using the best Random Forest model
y_pred_rf = best_rf.predict(X_test)

# Calculating evaluation metrics
acc_rf = accuracy_score(y_test, y_pred_rf)
recall_rf = recall_score(y_test, y_pred_rf)
prec_rf = precision_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf)

# Printing the classification report
print("--- Random Forest ---")
print(classification_report(y_test, y_pred_rf))

# Compute confusion matrix
cm_rf = confusion_matrix(y_test, y_pred_rf, labels=[1, 0])

# Create DataFrame for confusion matrix
df_rf = pd.DataFrame(data=cm_rf, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Printing the confusion matrix DataFrame
print("Confusion Matrix:")
print(df_rf)

# Plotting the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_rf, annot=True, fmt='d', cmap='Blues', cbar=False, square=True, linewidths=0.5)
plt.title('Confusion Matrix - Random Forest')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Calculate ROC AUC
y_prob_rf = best_rf.predict_proba(X_test)[:, 1]
roc_auc_rf = roc_auc_score(y_test, y_prob_rf)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob_rf)

# Print ROC AUC
print(f"ROC AUC: {roc_auc_rf:.4f}")

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, marker='.', label='Random Forest (AUC = %0.4f)' % roc_auc_rf)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Random Forest')
plt.legend()
plt.show()

# Calculate Sensitivity and Specificity
tn, fp, fn, tp = cm_rf.ravel()
sensitivity = tp / (tp + fn)
specificity = tn / (tn + fp)

# Print Sensitivity and Specificity
print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# --- Random Forest ---
#               precision    recall  f1-score   support
#
#            0       0.99      0.64      0.78     66892
#            1       0.27      0.94      0.41      9330
#
#     accuracy                           0.68     76222
#    macro avg       0.63      0.79      0.60     76222
# weighted avg       0.90      0.68      0.73     76222
#
# Confusion Matrix:
#           Predicted 1  Predicted 0
# Actual 1         8731          599
# Actual 0        24106        42786
# ROC AUC: 0.8379
# Sensitivity (Recall): 0.6396
# Specificity: 0.9358

# %% [markdown]
# Evaluation

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Assuming X_train, y_train, X_test, and y_test are already defined

# Initialize models with hyperparameters
logreg_tuning = LogisticRegression()
param_logreg = {'C': [1, 0.5, 0.1, 5, 9],
                'penalty': ['l1', 'l2', 'elasticnet']}

knn_tuning = KNeighborsClassifier()
param_knn = {'n_neighbors': [5, 7, 9],
             'weights': ['uniform', 'distance'],
             'p': [1, 2]}

dt_tuning = DecisionTreeClassifier()
param_dt = {'max_depth': [None, 4, 9, 15, 20, 50],
            'min_samples_leaf': [1, 4, 0.1, 2, 10],
            'max_features': [None, 0.2, 0.8, 2.0],
            'min_samples_split': [2, 9, 15, 25]}

rf_tuning = RandomForestClassifier()
param_rf = {'n_estimators': [100, 500, 1000],
            'max_depth': [None, 4, 6, 8],
            'min_samples_leaf': [1, 0.06, 3, 5],
            'min_samples_split': [2, 9, 15, 25],
            'max_features': ['auto', 'sqrt', 'log2'],
            'criterion': ['gini', 'entropy']}

# Apply SMOTE to balance the dataset
sm = SMOTE(random_state=42)
X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)

# Dictionary to store evaluation metrics
metrics_summary = {
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1-Score': []
}

# Logistic Regression
model_logreg_tuned = GridSearchCV(estimator=logreg_tuning, param_grid=param_logreg, cv=3, n_jobs=-1, verbose=1, scoring='recall')
model_logreg_tuned.fit(X_train_sm, y_train_sm)
y_pred_logreg = model_logreg_tuned.predict(X_test)
metrics_summary['Model'].append('Logistic Regression')
metrics_summary['Accuracy'].append(accuracy_score(y_test, y_pred_logreg))
metrics_summary['Precision'].append(precision_score(y_test, y_pred_logreg))
metrics_summary['Recall'].append(recall_score(y_test, y_pred_logreg))
metrics_summary['F1-Score'].append(f1_score(y_test, y_pred_logreg))

# KNN Classifier
model_knn_tuned = GridSearchCV(estimator=knn_tuning, param_grid=param_knn, cv=5, scoring='accuracy')
model_knn_tuned.fit(X_train_sm, y_train_sm)
y_pred_knn = model_knn_tuned.predict(X_test)
metrics_summary['Model'].append('KNN Classifier')
metrics_summary['Accuracy'].append(accuracy_score(y_test, y_pred_knn))
metrics_summary['Precision'].append(precision_score(y_test, y_pred_knn))
metrics_summary['Recall'].append(recall_score(y_test, y_pred_knn))
metrics_summary['F1-Score'].append(f1_score(y_test, y_pred_knn))

# Decision Tree Classifier
model_dt_tuned = GridSearchCV(estimator=dt_tuning, param_grid=param_dt, cv=5, scoring='accuracy')
model_dt_tuned.fit(X_train_sm, y_train_sm)
y_pred_dt = model_dt_tuned.predict(X_test)
metrics_summary['Model'].append('Decision Tree Classifier')
metrics_summary['Accuracy'].append(accuracy_score(y_test, y_pred_dt))
metrics_summary['Precision'].append(precision_score(y_test, y_pred_dt))
metrics_summary['Recall'].append(recall_score(y_test, y_pred_dt))
metrics_summary['F1-Score'].append(f1_score(y_test, y_pred_dt))

# Random Forest Classifier
model_rf_tuned = RandomizedSearchCV(estimator=rf_tuning, param_distributions=param_rf, scoring='recall', verbose=1, n_jobs=-1, cv=3)
model_rf_tuned.fit(X_train_sm, y_train_sm)
y_pred_rf = model_rf_tuned.predict(X_test)
metrics_summary['Model'].append('Random Forest Classifier')
metrics_summary['Accuracy'].append(accuracy_score(y_test, y_pred_rf))
metrics_summary['Precision'].append(precision_score(y_test, y_pred_rf))
metrics_summary['Recall'].append(recall_score(y_test, y_pred_rf))
metrics_summary['F1-Score'].append(f1_score(y_test, y_pred_rf))

# Create a DataFrame for the summary
df_summary = pd.DataFrame(metrics_summary)

# Print the summary table
print("--- Summary of Model Metrics ---")
print(df_summary)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 30 fits failed out of a total of 45.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1172, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py", line 67, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan 0.96917838        nan        nan 0.96917838        nan
#         nan 0.96917838        nan        nan 0.96917838        nan
#         nan 0.96917838        nan]
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 600 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 600 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 2.0 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.81893746 0.81211894 0.81021619 0.80774149 0.80473035 0.80505184
#  0.80528735 0.80475091 0.77816282 0.77816282 0.77816282 0.77816282
#  0.80702188 0.80950032 0.8088966  0.80750785 0.80086504 0.80085756
#  0.80084821 0.80116783 0.80693029 0.79799221 0.79639038 0.79526144
#  0.7851589  0.78635139 0.7876822  0.78984102 0.7322893  0.67657312
#  0.71607668 0.67274869 0.78796257 0.79214563 0.79330636 0.79401288
#  0.78917188 0.78833078 0.78870086 0.78944851 0.80915827 0.80033981
#  0.79922769 0.79743335 0.78996812 0.79105594 0.79310822 0.79352878
#  0.77448068 0.77028637 0.77389565 0.77530122 0.79272693 0.7957362
#  0.79636795 0.79678851 0.79247086 0.79236993 0.79252132 0.79300169
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.78985036 0.78985036 0.78985036 0.78985036
#  0.78984849 0.78984849 0.78984849 0.78984849 0.77816282 0.77816282
#  0.77816282 0.77816282 0.78985036 0.78985036 0.78985036 0.78985036
#  0.78984849 0.78984849 0.78984849 0.78984849 0.77114808 0.77777219
#  0.77701518 0.76450341 0.78182815 0.76867525 0.77101536 0.76707524
#  0.72395123 0.7086319  0.66710219 0.72677918 0.7720527  0.78477387
#  0.77133494 0.76817993 0.77799085 0.77794413 0.76655381 0.75638775
#  0.78984849 0.79041296 0.78984849 0.78985036 0.78984849 0.7864841
#  0.78657569 0.78984849 0.77439283 0.77419097 0.77816282 0.77456666
#  0.78984849 0.79064286 0.78984849 0.78984849 0.78833826 0.78984849
#  0.78657569 0.78851021        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.79746138 0.7974726
#  0.7974726  0.79748381 0.79749316 0.79749316 0.79749316 0.79749877
#  0.77816282 0.77816282 0.77816282 0.77816282 0.7975025  0.79750998
#  0.79750811 0.79751372 0.7974726  0.7974726  0.7974726  0.79747821
#  0.79317738 0.79256993 0.794054   0.79368951 0.7937998  0.79239609
#  0.79391755 0.796153   0.76812569 0.68796517 0.71749161 0.65994353
#  0.79279796 0.78912703 0.79359793 0.79420539 0.79461286 0.79344467
#  0.79205405 0.79298674 0.79673056 0.79775296 0.79704083 0.79737166
#  0.79676794 0.79652683 0.79730811 0.79709877 0.77713667 0.77407321
#  0.77766937 0.77448068 0.79690812 0.7963287  0.79692308 0.79674364
#  0.79674926 0.79664271 0.79690252 0.79685205        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.80201267 0.80188744 0.80174164 0.80133979 0.80179772 0.80179772
#  0.80169679 0.80135474 0.77816282 0.77816282 0.77816282 0.77816282
#  0.80202388 0.80193416 0.80182762 0.80144633 0.8013267  0.80133231
#  0.80132297 0.80120708 0.80000898 0.80006318 0.79942208 0.80005384
#  0.79832117 0.79936414 0.79826323 0.79923143 0.73111741 0.71954951
#  0.70344503 0.72345033 0.79858472 0.79842771 0.7980894  0.79993235
#  0.79645394 0.7992333  0.79827071 0.7977754  0.80132483 0.8007641
#  0.8016781  0.800637   0.80146128 0.80141455 0.80148932 0.80075663
#  0.77699836 0.77753667 0.77481712 0.77189197 0.80118091 0.80131549
#  0.80083139 0.80049495 0.80072485 0.8009454  0.79996786 0.80062766
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.80778261 0.80718449 0.80645554 0.805278
#  0.80631349 0.80633966 0.80589481 0.80484811 0.77816282 0.77816282
#  0.77816282 0.77816282 0.80720505 0.80702936 0.80640881 0.8053023
#  0.80418644 0.80420326 0.80419579 0.80394159 0.80513221 0.80375281
#  0.80317152 0.80294535 0.79973609 0.80205005 0.80043327 0.79989683
#  0.69843794 0.70329573 0.73334161 0.73079003 0.80485745 0.80307058
#  0.80152483 0.8016837  0.80065008 0.79848753 0.79758849 0.79969871
#  0.80596957 0.80535837 0.8048724  0.80393411 0.8040743  0.80450606
#  0.80419392 0.80325936 0.77751798 0.77448068 0.77456666 0.77763012
#  0.80513408 0.80554902 0.80407429 0.80348739 0.80217341 0.80311544
#  0.80267246 0.80162202        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.81963277 0.81367031
#  0.81131897 0.80882744 0.80691534 0.80722188 0.8070331  0.8060948
#  0.77816282 0.77816282 0.77816282 0.77816282 0.81001993 0.81131896
#  0.81015451 0.80846483 0.80206313 0.80213042 0.80216407 0.8022706
#  0.80807793 0.79898658 0.79710064 0.79666701 0.78681306 0.7864355
#  0.78912329 0.79036438 0.73692469 0.69064376 0.69461563 0.74404785
#  0.79080361 0.79373812 0.79333439 0.7946951  0.78939617 0.79003354
#  0.78764108 0.78989148 0.80982368 0.80193977 0.80003141 0.7991361
#  0.79196994 0.7920989  0.79363158 0.79445398 0.77479092 0.77051443
#  0.77387879 0.77548813 0.79553059 0.79727447 0.79777353 0.79820342
#  0.79224656 0.79245217 0.79304468 0.79389325        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 13 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 8 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\ensemble\_forest.py", line 489, in fit
#     trees = Parallel(
#             ^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\parallel.py", line 67, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\joblib\parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\joblib\parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\parallel.py", line 129, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\ensemble\_forest.py", line 192, in _parallel_build_trees
#     tree._fit(
#   File "D:\Anaconda\Lib\site-packages\sklearn\tree\_classes.py", line 472, in _fit
#     builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#   File "sklearn\\tree\\_tree.pyx", line 166, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\\tree\\_tree.pyx", line 285, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\\tree\\_tree.pyx", line 940, in sklearn.tree._tree.Tree._add_node
#   File "sklearn\\tree\\_tree.pyx", line 908, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn\\tree\\_utils.pyx", line 35, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 1048576 bytes
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "D:\Anaconda\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\ensemble\_forest.py", line 489, in fit
#     trees = Parallel(
#             ^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\parallel.py", line 67, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\joblib\parallel.py", line 1918, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\joblib\parallel.py", line 1847, in _get_sequential_output
#     res = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\utils\parallel.py", line 129, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\sklearn\ensemble\_forest.py", line 192, in _parallel_build_trees
#     tree._fit(
#   File "D:\Anaconda\Lib\site-packages\sklearn\tree\_classes.py", line 472, in _fit
#     builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#   File "sklearn\\tree\\_tree.pyx", line 166, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\\tree\\_tree.pyx", line 285, in sklearn.tree._tree.DepthFirstTreeBuilder.build
#   File "sklearn\\tree\\_tree.pyx", line 940, in sklearn.tree._tree.Tree._add_node
#   File "sklearn\\tree\\_tree.pyx", line 908, in sklearn.tree._tree.Tree._resize_c
#   File "sklearn\\tree\\_utils.pyx", line 35, in sklearn.tree._utils.safe_realloc
# MemoryError: could not allocate 4194304 bytes
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# D:\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.92088805        nan 0.94036792        nan        nan 0.8954233
#  0.89550928 0.90601367        nan        nan]
#   warnings.warn(
# --- Summary of Model Metrics ---
#                       Model  Accuracy  Precision    Recall  F1-Score
# 0       Logistic Regression  0.637336   0.249185  0.975027  0.396928
# 1            KNN Classifier  0.744772   0.219277  0.423794  0.289014
# 2  Decision Tree Classifier  0.747278   0.268817  0.618971  0.374842
# 3  Random Forest Classifier  0.676852   0.266347  0.934727  0.414565

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

# Convert confusion matrices to DataFrames
cm_logreg = confusion_matrix(y_test, model_logreg_tuned.predict(X_test), labels=[1, 0])
cm_knn = confusion_matrix(y_test, model_knn_tuned.predict(X_test), labels=[1, 0])
cm_rf = confusion_matrix(y_test, model_rf_tuned.predict(X_test), labels=[1, 0])
cm_dt = confusion_matrix(y_test, model_dt_tuned.predict(X_test), labels=[1, 0])

df_cm_logreg = pd.DataFrame(data=cm_logreg, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
df_cm_knn = pd.DataFrame(data=cm_knn, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
df_cm_rf = pd.DataFrame(data=cm_rf, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])
df_cm_dt = pd.DataFrame(data=cm_dt, index=["Actual 1", "Actual 0"], columns=["Predicted 1", "Predicted 0"])

# Combine DataFrames into one DataFrame with multi-level columns
df_cm_combined = pd.concat(
    [df_cm_logreg.add_suffix(' (LogReg)'), df_cm_knn.add_suffix(' (KNN)'), df_cm_rf.add_suffix(' (RF)'), df_cm_dt.add_suffix(' (DT)')],
    axis=1
)

# Print the combined DataFrame
print("Confusion Matrix Comparison")
print(df_cm_combined)
# Out:
# Confusion Matrix Comparison
#           Predicted 1 (LogReg)  Predicted 0 (LogReg)  Predicted 1 (KNN)  \
# Actual 1                  9097                   233               3954
# Actual 0                 27410                 39482              14078
#
#           Predicted 0 (KNN)  Predicted 1 (RF)  Predicted 0 (RF)  \
# Actual 1               5376              8721               609
# Actual 0              52814             24022             42870
#
#           Predicted 1 (DT)  Predicted 0 (DT)
# Actual 1              5775              3555
# Actual 0             15708             51184

# %%
import pandas as pd
from sklearn.metrics import roc_auc_score, roc_curve

# Dictionary to store detailed evaluation metrics
detailed_metrics_summary = {
    'Model': [],
    'Sensitivity (Recall)': [],
    'Specificity': [],
    'ROC AUC': []
}

# Logistic Regression
y_prob_logreg = model_logreg_tuned.predict_proba(X_test)[:, 1]
roc_auc_logreg = roc_auc_score(y_test, y_prob_logreg)
tn_logreg, fp_logreg, fn_logreg, tp_logreg = cm_logreg.ravel()
sensitivity_logreg = tp_logreg / (tp_logreg + fn_logreg)
specificity_logreg = tn_logreg / (tn_logreg + fp_logreg)
detailed_metrics_summary['Model'].append('Logistic Regression')
detailed_metrics_summary['Sensitivity (Recall)'].append(sensitivity_logreg)
detailed_metrics_summary['Specificity'].append(specificity_logreg)
detailed_metrics_summary['ROC AUC'].append(roc_auc_logreg)

# KNN Classifier
y_prob_knn = model_knn_tuned.predict_proba(X_test)[:, 1]
roc_auc_knn = roc_auc_score(y_test, y_prob_knn)
tn_knn, fp_knn, fn_knn, tp_knn = cm_knn.ravel()
sensitivity_knn = tp_knn / (tp_knn + fn_knn)
specificity_knn = tn_knn / (tn_knn + fp_knn)
detailed_metrics_summary['Model'].append('KNN Classifier')
detailed_metrics_summary['Sensitivity (Recall)'].append(sensitivity_knn)
detailed_metrics_summary['Specificity'].append(specificity_knn)
detailed_metrics_summary['ROC AUC'].append(roc_auc_knn)

# Random Forest Classifier
y_prob_rf = model_rf_tuned.predict_proba(X_test)[:, 1]
roc_auc_rf = roc_auc_score(y_test, y_prob_rf)
tn_rf, fp_rf, fn_rf, tp_rf = cm_rf.ravel()
sensitivity_rf = tp_rf / (tp_rf + fn_rf)
specificity_rf = tn_rf / (tn_rf + fp_rf)
detailed_metrics_summary['Model'].append('Random Forest Classifier')
detailed_metrics_summary['Sensitivity (Recall)'].append(sensitivity_rf)
detailed_metrics_summary['Specificity'].append(specificity_rf)
detailed_metrics_summary['ROC AUC'].append(roc_auc_rf)

# Decision Tree Classifier
y_prob_dt = model_dt_tuned.predict_proba(X_test)[:, 1]
roc_auc_dt = roc_auc_score(y_test, y_prob_dt)
tn_dt, fp_dt, fn_dt, tp_dt = cm_dt.ravel()
sensitivity_dt = tp_dt / (tp_dt + fn_dt)
specificity_dt = tn_dt / (tn_dt + fp_dt)
detailed_metrics_summary['Model'].append('Decision Tree Classifier')
detailed_metrics_summary['Sensitivity (Recall)'].append(sensitivity_dt)
detailed_metrics_summary['Specificity'].append(specificity_dt)
detailed_metrics_summary['ROC AUC'].append(roc_auc_dt)

# Create a DataFrame for the detailed summary
df_detailed_summary = pd.DataFrame(detailed_metrics_summary)

# Print the detailed summary table
print("--- Detailed Model Metrics Summary ---")
print(df_detailed_summary)
# Out:
# --- Detailed Model Metrics Summary ---
#                       Model  Sensitivity (Recall)  Specificity   ROC AUC
# 0       Logistic Regression              0.590235     0.975027  0.826707
# 1            KNN Classifier              0.789541     0.423794  0.675216
# 2  Random Forest Classifier              0.640884     0.934727  0.838903
# 3  Decision Tree Classifier              0.765174     0.618971  0.700553
